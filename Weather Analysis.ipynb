# %% [markdown]
# # Weather Data Analysis

# %% [markdown]
# ### The weather Dataset is a time-series dataset per-hour information about the weather conditions at a particular location. It records Temperature, Dew Point Temperature, Realtive Humidity, Wind speed, Visibility, Pressure and Weather Condition.

# %% [markdown]
# ### This data is available as a CSV file. We are going to analysis this dataset using the pandas dataframe.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import calendar
import datetime

df = pd.read_csv(r"C:\Users\alina\Desktop\Data Analysis Project\Weather Data.csv",parse_dates=True, index_col="Date/Time")
df.head()
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#                      Visibility_km  Press_kPa               Weather
# Date/Time
# 2012-01-01 00:00:00            8.0     101.24                   Fog
# 2012-01-01 01:00:00            8.0     101.24                   Fog
# 2012-01-01 02:00:00            4.0     101.26  Freezing Drizzle,Fog
# 2012-01-01 03:00:00            4.0     101.27  Freezing Drizzle,Fog
# 2012-01-01 04:00:00            4.8     101.23                   Fog

# %% [markdown]
# ## Q1. Provide basic information about the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8784 entries, 2012-01-01 00:00:00 to 2012-12-31 23:00:00
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Temp_C            8784 non-null   float64
#  1   Dew Point Temp_C  8784 non-null   float64
#  2   Rel Hum_%         8784 non-null   int64
#  3   Wind Speed_km/h   8784 non-null   int64
#  4   Visibility_km     8784 non-null   float64
#  5   Press_kPa         8784 non-null   float64
#  6   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 549.0+ KB

# %% [markdown]
# ## Q2. Shows the first N rows in the data (by default, N=5)

# %%
df.head()
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#                      Visibility_km  Press_kPa               Weather
# Date/Time
# 2012-01-01 00:00:00            8.0     101.24                   Fog
# 2012-01-01 01:00:00            8.0     101.24                   Fog
# 2012-01-01 02:00:00            4.0     101.26  Freezing Drizzle,Fog
# 2012-01-01 03:00:00            4.0     101.27  Freezing Drizzle,Fog
# 2012-01-01 04:00:00            4.8     101.23                   Fog

# %%
df[:5]
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#                      Visibility_km  Press_kPa               Weather
# Date/Time
# 2012-01-01 00:00:00            8.0     101.24                   Fog
# 2012-01-01 01:00:00            8.0     101.24                   Fog
# 2012-01-01 02:00:00            4.0     101.26  Freezing Drizzle,Fog
# 2012-01-01 03:00:00            4.0     101.27  Freezing Drizzle,Fog
# 2012-01-01 04:00:00            4.8     101.23                   Fog

# %% [markdown]
# ## Q3. Find out different weather condition available

# %%
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %% [markdown]
# ## Q4. Find out the number of times when the weather was exactly 'clear'

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
len(df[df.Weather == 'Clear']) #for exact value
# Out:
# 1326

# %%
#using count
df[(df.Weather == 'Clear')].count()[1]
# Out:
# 1326

# %% [markdown]
# ## Q5. Find all the unique wind speed values recorded in the dataset

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# ## Q6. Find the number of times when the wind speed was exactly 7Km/h

# %%
df['Wind Speed_km/h'].value_counts()[7]
# Out:
# 677

# %%
len(df[(df['Wind Speed_km/h'] == 7)])
# Out:
# 677

# %% [markdown]
# ## Q7. Get the weather and Temperature columns from the dataframe

# %%
df[['Weather', 'Temp_C']].head()
# Out:
#                                   Weather  Temp_C
# Date/Time
# 2012-01-01 00:00:00                   Fog    -1.8
# 2012-01-01 01:00:00                   Fog    -1.8
# 2012-01-01 02:00:00  Freezing Drizzle,Fog    -1.8
# 2012-01-01 03:00:00  Freezing Drizzle,Fog    -1.5
# 2012-01-01 04:00:00                   Fog    -1.5

# %% [markdown]
# ## Q8. First 20 rows from the dataframe

# %%
df[:20]
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
# 2012-01-01 05:00:00    -1.4              -3.3         87                9
# 2012-01-01 06:00:00    -1.5              -3.1         89                7
# 2012-01-01 07:00:00    -1.4              -3.6         85                7
# 2012-01-01 08:00:00    -1.4              -3.6         85                9
# 2012-01-01 09:00:00    -1.3              -3.1         88               15
# 2012-01-01 10:00:00    -1.0              -2.3         91                9
# ...

# %% [markdown]
# ## Q9. What were the first 5 pressure values recorded on jan 6.

# %%
df.loc['2012-01-06', 'Press_kPa'][:5]
# Out:
# Date/Time
# 2012-01-06 00:00:00    100.81
# 2012-01-06 01:00:00    100.81
# 2012-01-06 02:00:00    100.84
# 2012-01-06 03:00:00    100.76
# 2012-01-06 04:00:00    100.70
# Name: Press_kPa, dtype: float64

# %% [markdown]
# ## Q10. Find all instances when wind speed was above 30 and visibility was 25

# %%
df[(df['Wind Speed_km/h'] > 30) & (df['Visibility_km'] == 25)]
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-02 00:00:00     5.2               1.5         77               35
# 2012-01-02 01:00:00     4.6               0.0         72               39
# 2012-01-02 02:00:00     3.9              -0.9         71               32
# 2012-01-02 03:00:00     3.7              -1.5         69               33
# 2012-01-02 04:00:00     2.9              -2.3         69               32
# ...                     ...               ...        ...              ...
# 2012-12-16 07:00:00    -9.8             -14.9         66               32
# 2012-12-21 18:00:00     1.4               0.3         92               46
# 2012-12-23 01:00:00    -7.9             -11.8         74               32
# 2012-12-26 19:00:00    -9.6             -13.1         76               39
# 2012-12-26 22:00:00    -9.7             -12.8         78               37
#
#                      Visibility_km  Press_kPa        Weather
# ...

# %% [markdown]
# ## Q11. Which were the top 10 hottest temperature values and thier counts?

# %%
df['Temp_C'].value_counts().sort_values(ascending=False).head(10)
# Out:
# 16.6    65
# 1.1     58
# 0.8     47
# 1.5     45
# 19.3    44
# 21.1    43
# 2.6     43
# 0.4     41
# 1.3     40
# 14.6    39
# Name: Temp_C, dtype: int64

# %% [markdown]
# ## Q12. What is the mean temperature recorded by month?

# %%
#using pivot table
mean_temperature_df = df.pivot_table(values = 'Temp_C', index = df.index.month, aggfunc = np.mean)
mean_temperature_df
# Out:
#               Temp_C
# Date/Time
# 1          -7.371505
# 2          -4.225000
# 3           3.121237
# 4           7.009306
# 5          16.237769
# 6          20.134028
# 7          22.790054
# 8          22.279301
# 9          16.484444
# 10         10.954973
# 11          0.931389
# 12         -3.306317

# %% [markdown]
# ## Q13. Extract month name from the date and store in new column named as month

# %%
df['Month'] = df.index.month
df['Month'] = df['Month'].apply(lambda x: calendar.month_name[x])
df.head()
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#                      Visibility_km  Press_kPa               Weather    Month
# Date/Time
# 2012-01-01 00:00:00            8.0     101.24                   Fog  January
# 2012-01-01 01:00:00            8.0     101.24                   Fog  January
# 2012-01-01 02:00:00            4.0     101.26  Freezing Drizzle,Fog  January
# 2012-01-01 03:00:00            4.0     101.27  Freezing Drizzle,Fog  January
# 2012-01-01 04:00:00            4.8     101.23                   Fog  January
